# %%
import numpy as np

# %%
number_of_students = 200
coin_tosses = 5

coin_toss_results = np.random.binomial( n=coin_tosses, p=0.5, size=number_of_students)

print(coin_toss_results)
# Out:
# [1 1 1 1 2 3 3 1 3 1 1 3 4 3 1 3 2 2 3 3 2 3 0 3 1 2 2 2 2 3 3 2 2 1 1 3 2
#  4 3 2 3 3 3 4 1 4 3 4 4 2 4 1 1 1 2 3 3 2 4 3 1 1 3 3 2 1 2 4 1 4 3 2 4 2
#  3 3 3 2 4 2 3 1 4 3 2 2 2 2 3 4 4 2 4 4 3 2 2 2 2 1 3 3 0 1 3 4 2 2 3 4 1
#  2 2 1 3 3 3 3 2 3 1 0 4 1 3 3 3 0 5 2 2 1 2 2 1 2 2 4 2 2 2 3 3 2 5 2 2 2
#  3 3 4 3 1 3 0 1 1 2 5 2 3 2 4 1 3 3 2 0 4 1 2 4 2 4 4 2 1 2 4 3 3 3 3 3 2
#  2 5 4 3 3 4 2 3 3 2 4 3 4 3 2]

# %%
rf = list()
for num_heads in range(0, coin_tosses + 1):
    frequency_num_heads = np.count_nonzero(coin_toss_results == num_heads)
    print(frequency_num_heads/number_of_students)

    print (rf)
# Out:
# 0.03
# []
# 0.17
# []
# 0.305
# []
# 0.315
# []
# 0.16
# []
# 0.02
# []

# %%
coin_toss_results == 0
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
# %pip install matplotlib numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> This Python installation is managed by uv and should not be modified.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
number_of_experiments = 40000
num_bernoulli_trials = 10

num_desired_outcomes = list()
relative_frequency = list()

experiment_result = np.random.binomial(n=num_bernoulli_trials, p=0.8, size=number_of_experiments)

print(experiment_result)
# Out:
# [8 7 8 ... 9 8 6]

# %%
experiment_result == 0
# Out:
# array([False, False, False, ..., False, False, False], shape=(40000,))

# %%
for k in range(num_bernoulli_trials+1):
    frequency_num_heads = np.count_nonzero(experiment_result == k)
    rf = (frequency_num_heads/number_of_experiments)
    print(f"RF({k}) = {rf}")

    num_desired_outcomes.append(k)
    relative_frequency.append(rf)


    plt.xlabel("Number of people out of 10 people voting for BJP")
    plt.ylabel("Probabilty of k people out of 10 voting for BJP")
    plt.bar(num_desired_outcomes, relative_frequency)
# Out:
# RF(0) = 0.0
# RF(1) = 0.0
# RF(2) = 2.5e-05
# RF(3) = 0.000675
# RF(4) = 0.0051
# RF(5) = 0.02605
# RF(6) = 0.08655
# RF(7) = 0.19975
# RF(8) = 0.301425
# RF(9) = 0.271425
# RF(10) = 0.109

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
number_of_student = 40000000
mu = 170
sigma = 10

heights = np.random.normal(mu,sigma,size=number_of_student)

# %%
print(heights)
# Out:
# [178.43891987 181.64768422 166.07112942 ... 157.98387374 181.86989768
#  178.82262738]

# %%
min_height = np.min(heights)
max_height = np.max(heights)

print(f"Min Height = {min_height}")
print(f"Max Height = {max_height}")
# Out:
# Min Height = 115.44886960833524
# Max Height = 222.42619357861514

# %%
num_bins = 100
bin_width = (max_height - min_height)/num_bins
print(f"Bin Width = {bin_width}")
# Out:
# Bin Width = 1.069773239702799

# %%
plt.xlabel(f"{num_bins} bins from {min_height} to {max_height}")
plt.ylabel("Frequency of different bins")
plt.hist(heights, bins=num_bins)
# Out:
# (array([2.000000e+00, 1.000000e+00, 3.000000e+00, 7.000000e+00,
#         9.000000e+00, 1.400000e+01, 2.200000e+01, 3.700000e+01,
